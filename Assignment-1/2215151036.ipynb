# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Step 1: Generate two vectors with 15 random floats each, plot them on the same graph, label the axes, and add a title.

X = np.random.rand(15)
Y = np.random.rand(15)
print("Vector First:\n", X)
print("Vector Second:\n", Y)

plt.plot(X)
plt.plot(Y)
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Line Graph of Vector X and Y")
plt.show()
# Out:
# Vector X:
#  [0.21132248 0.40774151 0.36124655 0.54742014 0.53662123 0.7379026
#  0.00604425 0.07995689 0.04321013 0.84310041 0.66376831 0.261229
#  0.06203119 0.15208066 0.59212118]
# Vector Y:
#  [0.11945068 0.51106489 0.68926139 0.71703173 0.0512808  0.87103145
#  0.42785341 0.90995578 0.60551539 0.16506611 0.9117845  0.26196982
#  0.15833184 0.18824786 0.2207544 ]

# %%
#Step 2: Create a 4x4 matrix with random values, visualize it as a heatmap, and label the rows and columns.

Matrix = np.random.rand(4, 4)
print("Matrix:\n", Matrix)

sns.heatmap(Matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of 4x4 Matrix')
plt.show()
# Out:
# Matrix:
#  [[0.17400009 0.42732078 0.13398353 0.78268178]
#  [0.73445082 0.30949926 0.26915651 0.45309362]
#  [0.15620151 0.91695431 0.6557114  0.93491974]
#  [0.42505693 0.09919166 0.17077244 0.8378106 ]]

# %%
#Step 3: Generate two 4x4 matrices, perform addition, subtraction, and multiplication, visualize the results using bar plots, and discuss the effects.

Matrix1 = np.random.rand(4, 4)
Matrix2 = np.random.rand(4, 4)

print("Matrix 1:\n", Matrix1)
print("Matrix 2:\n", Matrix2)

Addition = Matrix1 + Matrix2
Subtraction = Matrix1 - Matrix2
Multiplication = Matrix1 * Matrix2

print("Addition:\n", Addition)
print("Subtraction:\n", Subtraction)
print("Multiplication:\n", Multiplication)

add_flat = Addition.flatten()
sub_flat = Subtraction.flatten()
mul_flat = Multiplication.flatten()

indices = np.arange(len(add_flat))


fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].bar(indices, add_flat, color='b')
axes[0].set_title('Matrix Addition')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Value')

axes[1].bar(indices, sub_flat, color='g')
axes[1].set_title('Matrix Subtraction')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Value')

axes[2].bar(indices, mul_flat, color='r')
axes[2].set_title('Matrix Multiplication')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Value')

plt.tight_layout()
plt.show()
# Out:
# Matrix 1:
#  [[0.7857107  0.91255288 0.25962767 0.80061702]
#  [0.24007913 0.10031306 0.00970353 0.29333141]
#  [0.00856798 0.59067899 0.59812008 0.98590986]
#  [0.57786253 0.48057804 0.88113918 0.63022015]]
# Matrix 2:
#  [[0.38325003 0.32430581 0.35319325 0.69157686]
#  [0.53758962 0.35987174 0.25419199 0.78525955]
#  [0.99449562 0.03403269 0.2890498  0.94245088]
#  [0.73459872 0.91843926 0.16302075 0.70333279]]
# Addition:
#  [[1.16896073 1.23685869 0.61282092 1.49219388]
#  [0.77766874 0.4601848  0.26389552 1.07859097]
#  [1.0030636  0.62471168 0.88716988 1.92836075]
#  [1.31246125 1.3990173  1.04415994 1.33355294]]
# Subtraction:
#  [[ 0.40246067  0.58824708 -0.09356558  0.10904016]
#  [-0.29751049 -0.25955868 -0.24448845 -0.49192814]
#  [-0.98592764  0.55664629  0.30907027  0.04345898]
#  [-0.15673619 -0.43786122  0.71811843 -0.07311264]]
# Multiplication:
#  [[0.30112365 0.2959462  0.09169874 0.55368821]
#  [0.12906405 0.03609984 0.00246656 0.2303413 ]
# ...
